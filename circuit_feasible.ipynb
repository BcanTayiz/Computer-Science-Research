# %% [markdown]
# # Source
#
# * https://courses.engr.illinois.edu/cs573/fa2010/notes/30-nphard.pdf

# %%
import random

class CircuitFeasible:

    def __init__(self, n,cond):
        self.n = n
        self.vals = [random.uniform(0, 1) < 0.5 for _ in range(5)]
        self.starter_cond = cond

    def OrGate(self, val1, val2):
        return val1 or val2

    def AndGate(self, val1, val2):
        return val1 and val2  # Fixed the logic of the AND gate

    def NorGate(self, val1):
        return not val1

    def simulation(self, n, val):
        for i in range(n):
            process = [int(random.uniform(0, 3)) for _ in range(int(random.uniform(0, 10)))]
            vals = random.choices(self.vals, k=int(random.uniform(1, len(self.vals))))

            for process_val in process:
                chosen_vals = random.choices(vals, k=1)
                if process_val == 0:
                    val = self.OrGate(val, chosen_vals[0])
                elif process_val == 1:
                    val = self.AndGate(val, chosen_vals[0])
                else:
                    val = self.NorGate(val)

        return val

    def createSystem(self):
        transformed_result = []
        processes = [self.AndGate,self.OrGate]
        final_comb = None
        for val in self.vals:
            result = self.simulation(3, val)
            transformed_result.append(result)
        
        for i in range(10):
            x = random.choice(transformed_result)
            y = random.choice(transformed_result)

            process = random.choice(processes)

            final_comb = process(x,y)

        return final_comb

# %%
# Example usage:


boolsValSums = []
for iter in range(10,10000):
    circ = CircuitFeasible(iter)
    print(iter)
    boolVals = []
    for i in range(1000):
        final_comb = circ.createSystem()
        boolVals.append(final_comb)
    
    boolsValSums.append(sum(boolVals))

# %%
import matplotlib.pyplot as plt
plt.plot([i for i in range(len(boolsValSums))], sorted(boolsValSums), linestyle='-', color='b',label="values")
plt.xlabel('Number of Iterations')
plt.ylabel('Execution Time (seconds)')
plt.title('Execution Time vs Number of Iterations')
plt.grid(True)
plt.show()

# %%
def OrGate(val1, val2):
        return val1 or val2

def AndGate(val1, val2):
    return val1 and val2  # Fixed the logic of the AND gate

def NorGate(val1):
    return not val1

# %%
for i in range(10000):
    result = AndGate(random.uniform(0,1)<0.5,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    result = AndGate(result,random.uniform(0,1)<0.5)
    if result:
        print(result)
